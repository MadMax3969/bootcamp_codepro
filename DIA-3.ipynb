# %%
# Challenge 1 🤺 - 15m
# Crear una función que imprima la variable palabra.


palabra = input('Ingrese alguna palabra')

def variable():
    print('Has puesto',palabra)
   

variable()
# Out:
# Has puesto hoja

# %%
# Challenge 2 🤺 - 15 min
# Crear una función que reciba dos letras (parámetros) y que verifique si son iguales:

# Si son iguales, imprimir "Las letras son iguales".

# De lo contrario, imprimir "Las letras son diferentes".


def recibir(letra1,letra2):
    if letra1 == letra2:
        print('Las letras son iguales')

    else:
        print('Las letras son diferentes')

recibir(letra1 =input('Ingrese una letra'), letra2 =input('Ingrese otra letra'))
# Out:
# Las letras son diferentes

# %%
# Challenge 3 🤺 - 20m
# Crear una función que reciba dos parámetros (una palabra y un número), y que retorne True si el número es igual a la cantidad de 
# letras de la palabra. En caso contrario, que retorne False.
# imprimir resultado de la funcion
# Pista: cantidad de letras de una palabra en python


def recibir(palabra,numero):
    if len(palabra) == numero:
        return True
    
    else:
        return False
    
carga_datos = recibir(palabra = input('Ingrese una palabra'),numero = int(input('Ingrese un numero')))
print(carga_datos)
# Out:
# False

# %%
# Challenge 5 🤺 - 25m
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list(). 
# Agregar esa lista de caracteres a una lista llamada palabras_ingresadas. Repetir el proceso 3 veces. 
# Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas.


# Ejemplo del resultado esperado:

# [['c', 'i', 'e', 'l', 'o']]
#  # Al ingresar la primera palabra

# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
#  # Al ingresar la segunda palabra

# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]
#  # Al ingresar la tercera palabra


palabra_usuario_1 = input('Ingrese una palabra')
palabras_ingresadas = list(palabra_usuario_1)

print (palabras_ingresadas)

palabra_usuario_2 = input('Ingrese otra palabra')
palabras_ingresadas_2 = list(palabra_usuario_2)

print(palabras_ingresadas, palabras_ingresadas_2)

palabra_usuario_3 = input('Ingrese otra palabra')
palabras_ingresadas_3 = list(palabra_usuario_3)

print(palabras_ingresadas,palabras_ingresadas_2,palabras_ingresadas_3)
# Out:
# ['h', 'o', 'l', 'a']
# ['h', 'o', 'l', 'a'] ['j', 'o', 'r', 'g', 'e']
# ['h', 'o', 'l', 'a'] ['j', 'o', 'r', 'g', 'e'] ['k', 'p']

# %%
# Challenge 6 🤺 - 25m
# Dada la lista de ejemplo: 

# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.

# Ejemplo del resultado esperado:

# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']



lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

def descomposicion(lista):    #mi funcion es descomposicion   y trabaja con (lista)  
    for fila  in lista:      # fila es mi sublista, entonces lo que va a hacer  for es darle los datos con in de mi lista a mi sublista que es fila
    
     print(fila)


descomposicion(lista)     # aqui llamo a mi funcion que trabaje con lista
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
